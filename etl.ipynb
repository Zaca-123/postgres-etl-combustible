# %% [markdown]
# > ### ETL para la carga de *`datasets`* de transferencias de vehiculos en Argentina.

# %% [markdown]
# > #### Extracción

# %% [markdown]
# ##### Instalamos las librerias necesarias para el ETL

# %%
# Una vez instaladas, las comentamos para saltear el paso.
#!pip install pandas
#!pip install sqlalchemy
#!pip install psycopg2-binary

#!pip se utiliza en entornos como Google Colab, jupyter, etc.
# pip se utiliza en entornos como Windows, en la terminar de powershell, etc.

# %% [markdown]
# - Importamos las librerias de Python para la realizacion del ETL.

# %%
import logging
import sys
module_path = './'
sys.path.append(module_path)
import pandas as pd
from sqlalchemy import create_engine

logging.basicConfig(level=logging.INFO)

# %% [markdown]
# - Cargamos los dataset que fueron obtenidos desde la pagina de datos abiertos de argentina
# [https://www.datos.gob.ar/](https://www.datos.gob.ar/)
#
# Cuando cargas un DataFrame desde un archivo CSV en Pandas y deseas establecer una columna específica como índice, puedes hacerlo mediante el parámetro ***`index_col`*** en la función read_csv(). Simplemente especifica el nombre de la columna que deseas utilizar como índice y Pandas configurará el índice en función de los valores de esa columna.

# %%
url = "https://datos.jus.gob.ar/dataset/f6932e82-a039-4462-968d-7dcda77d1a3e/resource/ff17485b-6711-405f-b628-676216e4d9e0/download/dnrpa-transferencias-autos-202504.csv"

departamentos_df = pd.read_csv('./datos/departamentos.csv', index_col='id')
provincia_df = pd.read_csv('./datos/provincias.csv', index_col='id')
registro_df = pd.read_csv('./datos/listado-registros-seccionales-202504.csv', index_col='codigo')

# Descargo el csv desde la url donde lo actualizan a diario.
transferencias_df = pd.read_csv(url, encoding='utf-8-sig', sep=',', low_memory=False)

# %%
#Muestra las primeras 5 filas del DataFrame transferencias_df.
transferencias_df.head()
# Out:
#                        tramite_tipo tramite_fecha fecha_inscripcion_inicial  \
# 0            TRANSFERENCIA NACIONAL    2025-04-01                1984-07-03
# 1            TRANSFERENCIA NACIONAL    2025-04-01                2007-11-26
# 2   TRANSFERENCIA NACIONAL C/PEDIDO    2025-04-01                2019-01-25
# 3            TRANSFERENCIA NACIONAL    2025-04-01                2001-01-22
# 4  TRANSFERENCIA IMPORTADO C/PEDIDO    2025-04-01                2011-04-19
#
#    registro_seccional_codigo registro_seccional_descripcion  \
# 0                       1146                     MERLO Nº 2
# 1                       1146                     MERLO Nº 2
# 2                       1146                     MERLO Nº 2
# 3                       1146                     MERLO Nº 2
# 4                       1146                     MERLO Nº 2
#
#   registro_seccional_provincia automotor_origen  automotor_anio_modelo  \
# 0                 Buenos Aires         Nacional                 1984.0
# 1                 Buenos Aires         Nacional                 2007.0
# 2                 Buenos Aires         Nacional                 2019.0
# 3                 Buenos Aires         Nacional                 2001.0
# 4                 Buenos Aires     Protocolo 21                 2011.0
#
#   automotor_tipo_codigo automotor_tipo_descripcion  ...  \
# 0                    12                    PICK-UP  ...
# 1                    17               SEDAN 5 PTAS  ...
# 2                    22                     FURGON  ...
# 3                    13            RURAL 3 PUERTAS  ...
# 4                    05               SEDAN 5 PTAS  ...
#
#   automotor_uso_descripcion titular_tipo_persona titular_domicilio_localidad  \
# 0                   Privado               Física                    LIBERTAD
# 1                   Privado               Física              GONZALEZ CATAN
# 2                   Privado               Física                       MERLO
# 3                   Privado               Física          CIUDAD DE LIBERTAD
# 4                   Privado               Física           PARQUE SAN MARTIN
#
#   titular_domicilio_provincia  titular_genero titular_anio_nacimiento  \
# 0                BUENOS AIRES       Masculino                    1998
# 1                BUENOS AIRES       Masculino                    1990
# 2                BUENOS AIRES       Masculino                    1997
# 3                BUENOS AIRES        Femenino                    1967
# 4                BUENOS AIRES        Femenino                    1955
#
#   titular_pais_nacimiento titular_porcentaje_titularidad  \
# 0               ARGENTINA                          100.0
# 1               ARGENTINA                          100.0
# 2               ARGENTINA                          100.0
# 3               ARGENTINA                          100.0
# 4               ARGENTINA                           50.0
#
#   titular_domicilio_provincia_id titular_pais_nacimiento_id
# 0                              6                      200.0
# 1                              6                      200.0
# 2                              6                      200.0
# 3                              6                      200.0
# 4                              6                      200.0
#
# [5 rows x 25 columns]

# %% [markdown]
# > ### Conexión a la base de datos PostgreSQL

# %% [markdown]
# - Generamos la conexiøn al servidor de ***`PostgreSQL`***

# %%
engine = create_engine('postgresql://postgres:postgres@localhost/postgres?client_encoding=utf8')

# %% [markdown]
# > #### Transformación

# %% [markdown]
# - Visualizamos los datos que fueron cargados en el dataframe ***`provincia_df`***

# %%
#Muestra las primeras 5 filas del DataFrame provincia_df.
provincia_df.head()
# Out:
#           categoria  centroide_lat  centroide_lon fuente iso_id  \
# id
# 2   Ciudad Autonoma     -34.614442     -58.445876    IGN   AR-C
# 58        Provincia     -38.641983     -70.119897    IGN   AR-Q
# 74        Provincia     -33.761104     -66.025231    IGN   AR-D
# 82        Provincia     -30.708823     -60.950687    IGN   AR-S
# 46        Provincia     -29.684937     -67.181758    IGN   AR-F
#
#                          iso_nombre                           nombre  \
# id
# 2   Ciudad Autonoma de Buenos Aires  Ciudad Autonoma de Buenos Aires
# 58                          Neuquen                          Neuquen
# 74                         San Luis                         San Luis
# 82                         Santa Fe                         Santa Fe
# 46                         La Rioja                         La Rioja
#
#                     nombre_completo
# id
# 2   Ciudad Autonoma de Buenos Aires
# 58            Provincia del Neuquen
# 74            Provincia de San Luis
# 82            Provincia de Santa Fe
# 46            Provincia de La Rioja

# %%
columnas_deseadas = ['nombre', 'nombre_completo', 'centroide_lat', 'centroide_lon', 'categoria']
provincia_transformado_df = provincia_df[columnas_deseadas]
provincia_transformado_df.head()
# Out:
#                              nombre                  nombre_completo  \
# id
# 2   Ciudad Autonoma de Buenos Aires  Ciudad Autonoma de Buenos Aires
# 58                          Neuquen            Provincia del Neuquen
# 74                         San Luis            Provincia de San Luis
# 82                         Santa Fe            Provincia de Santa Fe
# 46                         La Rioja            Provincia de La Rioja
#
#     centroide_lat  centroide_lon        categoria
# id
# 2      -34.614442     -58.445876  Ciudad Autonoma
# 58     -38.641983     -70.119897        Provincia
# 74     -33.761104     -66.025231        Provincia
# 82     -30.708823     -60.950687        Provincia
# 46     -29.684937     -67.181758        Provincia

# %% [markdown]
# > #### Carga

# %% [markdown]
# ##### Carga de datos en el servidor
#
# Cuando cargamos datos en el servidor utilizando la función `to_sql` de Pandas, el parámetro `if_exists` especifica qué hacer si la tabla ya existe en la base de datos. Aquí están las opciones disponibles:
#
# - **'fail'**: Esta es la opción predeterminada. Si la tabla ya existe, se generará un error y no se realizará ninguna acción.
# - **'replace'**: Si la tabla ya existe, se eliminará y se creará una nueva tabla con los datos del DataFrame.
# - **'append'**: Si la tabla ya existe, los nuevos datos se agregarán al final de la tabla existente.
#
# Cuando estableces el parámetro `index` en `False` en la función `to_sql` de Pandas, estás indicando que no deseas incluir el índice del DataFrame como una columna en la tabla de la base de datos. El índice en un DataFrame de Pandas es una serie de etiquetas que identifican de forma única cada fila. Por defecto, Pandas incluirá el índice como una columna en la tabla de la base de datos cuando se utiliza `to_sql`.

# %%
# Nombre de la tabla en la base de datos
nombre_tabla = 'provincia'
# Cargar el DataFrame en la tabla de PostgreSQL
provincia_transformado_df.to_sql(nombre_tabla, engine, if_exists='append', index=True, index_label='id')
# Cerrar la conexión a la base de datos
engine.dispose()
logging.info("DataFrame cargado en PostgreSQL correctamente.")

# %% [markdown]
# - Visualizamos los datos que fueron cargados en el dataframe ***`departamentos_df`***

# %%
departamentos_df.head()
# Out:
#           categoria  centroide_lat  centroide_lon fuente  \
# id
# 6014        Partido     -37.964616     -60.248282    IGN
# 30015  Departamento     -31.290298     -58.237870    IGN
# 30035  Departamento     -30.992427     -58.891860    IGN
# 30056  Departamento     -33.022349     -58.785805    IGN
# 30063  Departamento     -33.624996     -58.933896    IGN
#
#                        nombre                    nombre_completo  \
# id
# 6014   Adolfo Gonzales Chaves  Partido de Adolfo Gonzales Chaves
# 30015               Concordia             Departamento Concordia
# 30035                 Federal               Departamento Federal
# 30056            Gualeguaychú          Departamento Gualeguaychú
# 30063        Islas del Ibicuy      Departamento Islas del Ibicuy
#
#        provincia_id  provincia_interseccion provincia_nombre
# id
# 6014              6                0.012582     Buenos Aires
# 30015            30                0.041468       Entre Ríos
# 30035            30                0.065743       Entre Ríos
# 30056            30                0.097076       Entre Ríos
# 30063            30                0.064137       Entre Ríos

# %%
columnas_deseadas = ['nombre', 'nombre_completo', 'centroide_lat', 'centroide_lon', 'categoria', 'provincia_id']
departamentos_transformado_df = departamentos_df[columnas_deseadas]
departamentos_transformado_df.head()
# Out:
#                        nombre                    nombre_completo  \
# id
# 6014   Adolfo Gonzales Chaves  Partido de Adolfo Gonzales Chaves
# 30015               Concordia             Departamento Concordia
# 30035                 Federal               Departamento Federal
# 30056            Gualeguaychú          Departamento Gualeguaychú
# 30063        Islas del Ibicuy      Departamento Islas del Ibicuy
#
#        centroide_lat  centroide_lon     categoria  provincia_id
# id
# 6014      -37.964616     -60.248282       Partido             6
# 30015     -31.290298     -58.237870  Departamento            30
# 30035     -30.992427     -58.891860  Departamento            30
# 30056     -33.022349     -58.785805  Departamento            30
# 30063     -33.624996     -58.933896  Departamento            30

# %%
# Nombre de la tabla en la base de datos
nombre_tabla = 'departamento'
# Cargar el DataFrame en la tabla de PostgreSQL
departamentos_transformado_df.to_sql(nombre_tabla, engine, if_exists='append', index=True, index_label='id')
# Cerrar la conexión a la base de datos
engine.dispose()
logging.info("DataFrame cargado en PostgreSQL correctamente.")

# %% [markdown]
# ### Terminamos el proceso para todos los DF

# %%
transferencias_df.head()
# Out:
#                        tramite_tipo tramite_fecha fecha_inscripcion_inicial  \
# 0            TRANSFERENCIA NACIONAL    2025-04-01                1984-07-03
# 1            TRANSFERENCIA NACIONAL    2025-04-01                2007-11-26
# 2   TRANSFERENCIA NACIONAL C/PEDIDO    2025-04-01                2019-01-25
# 3            TRANSFERENCIA NACIONAL    2025-04-01                2001-01-22
# 4  TRANSFERENCIA IMPORTADO C/PEDIDO    2025-04-01                2011-04-19
#
#    registro_seccional_codigo registro_seccional_descripcion  \
# 0                       1146                     MERLO Nº 2
# 1                       1146                     MERLO Nº 2
# 2                       1146                     MERLO Nº 2
# 3                       1146                     MERLO Nº 2
# 4                       1146                     MERLO Nº 2
#
#   registro_seccional_provincia automotor_origen  automotor_anio_modelo  \
# 0                 Buenos Aires         Nacional                 1984.0
# 1                 Buenos Aires         Nacional                 2007.0
# 2                 Buenos Aires         Nacional                 2019.0
# 3                 Buenos Aires         Nacional                 2001.0
# 4                 Buenos Aires     Protocolo 21                 2011.0
#
#   automotor_tipo_codigo automotor_tipo_descripcion  ...  \
# 0                    12                    PICK-UP  ...
# 1                    17               SEDAN 5 PTAS  ...
# 2                    22                     FURGON  ...
# 3                    13            RURAL 3 PUERTAS  ...
# 4                    05               SEDAN 5 PTAS  ...
#
#   automotor_uso_descripcion titular_tipo_persona titular_domicilio_localidad  \
# 0                   Privado               Física                    LIBERTAD
# 1                   Privado               Física              GONZALEZ CATAN
# 2                   Privado               Física                       MERLO
# 3                   Privado               Física          CIUDAD DE LIBERTAD
# 4                   Privado               Física           PARQUE SAN MARTIN
#
#   titular_domicilio_provincia  titular_genero titular_anio_nacimiento  \
# 0                BUENOS AIRES       Masculino                    1998
# 1                BUENOS AIRES       Masculino                    1990
# 2                BUENOS AIRES       Masculino                    1997
# 3                BUENOS AIRES        Femenino                    1967
# 4                BUENOS AIRES        Femenino                    1955
#
#   titular_pais_nacimiento titular_porcentaje_titularidad  \
# 0               ARGENTINA                          100.0
# 1               ARGENTINA                          100.0
# 2               ARGENTINA                          100.0
# 3               ARGENTINA                          100.0
# 4               ARGENTINA                           50.0
#
#   titular_domicilio_provincia_id titular_pais_nacimiento_id
# 0                              6                      200.0
# 1                              6                      200.0
# 2                              6                      200.0
# 3                              6                      200.0
# 4                              6                      200.0
#
# [5 rows x 25 columns]

# %%
columnas_deseadas = ['registro_seccional_descripcion','tramite_fecha','automotor_origen','automotor_anio_modelo','automotor_tipo_codigo','automotor_tipo_descripcion','automotor_modelo_descripcion']
transferencias_transformado_df = transferencias_df[columnas_deseadas]

transferencias_transformado_df.head()
# Out:
#   registro_seccional_descripcion tramite_fecha automotor_origen  \
# 0                     MERLO Nº 2    2025-04-01         Nacional
# 1                     MERLO Nº 2    2025-04-01         Nacional
# 2                     MERLO Nº 2    2025-04-01         Nacional
# 3                     MERLO Nº 2    2025-04-01         Nacional
# 4                     MERLO Nº 2    2025-04-01     Protocolo 21
#
#    automotor_anio_modelo automotor_tipo_codigo automotor_tipo_descripcion  \
# 0                 1984.0                    12                    PICK-UP
# 1                 2007.0                    17               SEDAN 5 PTAS
# 2                 2019.0                    22                     FURGON
# 3                 2001.0                    13            RURAL 3 PUERTAS
# 4                 2011.0                    05               SEDAN 5 PTAS
#
#         automotor_modelo_descripcion
# 0                       F-100 / 1984
# 1                  206 X-LINE 1.4 5P
# 2  SPRINTER 411 CDI/F 3250 STREET V1
# 3                          PARPADDAA
# 4                             FIT LX

# %%
# Nombre de la tabla en la base de datos
nombre_tabla = 'transferencia'
# Cargar el DataFrame en la tabla de PostgreSQL
transferencias_transformado_df.to_sql(nombre_tabla, engine, if_exists='replace', index=True, index_label='id')
# Cerrar la conexión a la base de datos
engine.dispose()
logging.info("DataFrame cargado en PostgreSQL correctamente.")

# %%
import os
from dotenv import load_dotenv
import psycopg2

load_dotenv()  # carga variables del .env

print("PASSWORD:", repr(os.getenv("DATABASE_PASSWORD")))

conn = psycopg2.connect(
    host=os.getenv("DATABASE_HOST"),
    port=os.getenv("DATABASE_PORT"),
    dbname=os.getenv("DATABASE_NAME"),
    user=os.getenv("DATABASE_USER"),
    password=os.getenv("DATABASE_PASSWORD")
)

print("Conexión OK")
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[46], line 3
#       1 import psycopg2
# ----> 3 conn = psycopg2.connect(
#       4     host=os.getenv("DATABASE_HOST"),
#       5     port=os.getenv("DATABASE_PORT"),
#       6     dbname=os.getenv("DATABASE_NAME"),
#       7     user=os.getenv("DATABASE_USER"),
#       8     password=os.getenv("DATABASE_PASSWORD")
#       9 )
#      10 print("Conexión OK")
#      11 conn.close()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\psycopg2\__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: connection to server at "localhost" (::1), port 5432 failed: fe_sendauth: no password supplied
